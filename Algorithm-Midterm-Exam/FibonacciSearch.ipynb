# %%
import random
import time
import timeit

start = time.time()
 
def fibonacciSearch(arr, x):
 
    # Initialize fibonacci numbers
    fib2 = 0  # 第 (n-2) 個 Fibonacci 數
    fib1 = 1  # 第 (n-1) 個 Fibonacci 數
    fib = fib2 + fib1  # 第 n 個 Fibonacci 數
 
    # fib is going to store the smallest
    # Fibonacci Number greater than or equal to n
    while (fib < len(arr)):
        fib2 = fib1
        fib1 = fib
        fib = fib2 + fib1
 
    # Marks the eliminated range from front
    offset = -1
 
    # while there are elements to be inspected.
    # Note that we compare arr[fib2] with x.
    # When fib becomes 1, fib2 becomes 0
    while (fib > 1):
 
        # Check if fib2 is a valid location
        i = min(offset + fib2, len(arr) - 1)
 
        # If x is greater than the value at
        # index fib2, cut the subarray array
        # from offset to i
        if (arr[i] < x):
            fib = fib1
            fib1 = fib2
            fib2 = fib - fib1
            offset = i
 
        # If x is less than the value at
        # index fib2, cut the subarray
        # after i+1
        elif (arr[i] > x):
            fib = fib2
            fib1 = fib1 - fib2
            fib2 = fib - fib1
 
        # 找到該元素，return i
        else:
            return i
 
    # comparing the last element with x */
    if(fib1 and arr[len(arr) - 1] == x):
        return len(arr) - 1
 
    # 找不到該元素，return -1
    return -1

n_values = range(10, 1010, 10)
fibonacci_times = []

# Loop over different n values
for n in n_values:

    # Initialize list S with random integers
    S = [random.randint(1, 1000) for _ in range(n)]

    # 選擇 integer x
    x = random.randint(1, 1000)

    # 執行演算法5次，並計算平均執行時間
    fibonacci_time = timeit.timeit(lambda: fibonacciSearch(S, x), number = 5) / 5

    # 將每一次的平均執行時間 Append 到 list 中
    fibonacci_times.append(fibonacci_time)
    print("第", len(fibonacci_times), "次，S =", len(fibonacci_times) * 10, "時，執行的時間為", fibonacci_times[(n // 10) - 1])

# 結束測量
end = time.time()

# 輸出結果
print("總執行時間：%f 秒" % (end - start))
# Out:
# 第 1 次，S = 10 時，執行的時間為 1.8799999999430383e-06
# 第 2 次，S = 20 時，執行的時間為 1.7199999994943483e-06
# 第 3 次，S = 30 時，執行的時間為 2.4799999998492696e-06
# 第 4 次，S = 40 時，執行的時間為 2.13999999942871e-06
# 第 5 次，S = 50 時，執行的時間為 2.920000000017353e-06
# 第 6 次，S = 60 時，執行的時間為 3.840000000110421e-06
# 第 7 次，S = 70 時，執行的時間為 2.5199999996061708e-06
# 第 8 次，S = 80 時，執行的時間為 2.9800000000079764e-06
# 第 9 次，S = 90 時，執行的時間為 3.2400000002041907e-06
# 第 10 次，S = 100 時，執行的時間為 2.899999999783631e-06
# 第 11 次，S = 110 時，執行的時間為 2.3599999998680232e-06
# 第 12 次，S = 120 時，執行的時間為 2.280000000354221e-06
# 第 13 次，S = 130 時，執行的時間為 2.300000000587943e-06
# 第 14 次，S = 140 時，執行的時間為 2.4799999998492696e-06
# 第 15 次，S = 150 時，執行的時間為 2.5800000003073364e-06
# 第 16 次，S = 160 時，執行的時間為 2.840000000503551e-06
# 第 17 次，S = 170 時，執行的時間為 2.6400000002979596e-06
# 第 18 次，S = 180 時，執行的時間為 2.5799999995967935e-06
# 第 19 次，S = 190 時，執行的時間為 3.459999999932961e-06
# 第 20 次，S = 200 時，執行的時間為 3.300000000194814e-06
# 第 21 次，S = 210 時，執行的時間為 2.840000000503551e-06
# 第 22 次，S = 220 時，執行的時間為 5.8799999997916075e-06
# 第 23 次，S = 230 時，執行的時間為 3.0199999997648775e-06
# 第 24 次，S = 240 時，執行的時間為 2.6399999995874167e-06
# 第 25 次，S = 250 時，執行的時間為 2.6599999998211388e-06
# 第 26 次，S = 260 時，執行的時間為 3.060000000232321e-06
# 第 27 次，S = 270 時，執行的時間為 4.880000000184737e-06
# 第 28 次，S = 280 時，執行的時間為 3.5599999996804854e-06
# 第 29 次，S = 290 時，執行的時間為 3.0399999999985995e-06
# 第 30 次，S = 300 時，執行的時間為 3.439999999699239e-06
# 第 31 次，S = 310 時，執行的時間為 3.6999999998954534e-06
# 第 32 次，S = 320 時，執行的時間為 4.059999999839193e-06
# 第 33 次，S = 330 時，執行的時間為 3.459999999932961e-06
# 第 34 次，S = 340 時，執行的時間為 3.25999999972737e-06
# 第 35 次，S = 350 時，執行的時間為 3.0199999997648775e-06
# 第 36 次，S = 360 時，執行的時間為 2.9800000000079764e-06
# 第 37 次，S = 370 時，執行的時間為 3.960000000091668e-06
# 第 38 次，S = 380 時，執行的時間為 5.019999999689162e-06
# 第 39 次，S = 390 時，執行的時間為 9.060000000005175e-06
# 第 40 次，S = 400 時，執行的時間為 4.839999999717293e-06
# 第 41 次，S = 410 時，執行的時間為 3.42000000017606e-06
# 第 42 次，S = 420 時，執行的時間為 4.6199999999885225e-06
# 第 43 次，S = 430 時，執行的時間為 3.98000000032539e-06
# 第 44 次，S = 440 時，執行的時間為 4.6199999999885225e-06
# 第 45 次，S = 450 時，執行的時間為 4.6199999999885225e-06
# 第 46 次，S = 460 時，執行的時間為 3.6600000001385523e-06
# 第 47 次，S = 470 時，執行的時間為 4.640000000222244e-06
# 第 48 次，S = 480 時，執行的時間為 4.200000000054161e-06
# 第 49 次，S = 490 時，執行的時間為 4.660000000455966e-06
# 第 50 次，S = 500 時，執行的時間為 4.679999999979145e-06
# 第 51 次，S = 510 時，執行的時間為 4.5799999995210784e-06
# 第 52 次，S = 520 時，執行的時間為 3.3799999997086163e-06
# 第 53 次，S = 530 時，執行的時間為 3.2600000004379128e-06
# 第 54 次，S = 540 時，執行的時間為 3.7800000001197986e-06
# 第 55 次，S = 550 時，執行的時間為 3.300000000194814e-06
# 第 56 次，S = 560 時，執行的時間為 7.560000000239597e-06
# 第 57 次，S = 570 時，執行的時間為 4.060000000549735e-06
# 第 58 次，S = 580 時，執行的時間為 3.459999999932961e-06
# 第 59 次，S = 590 時，執行的時間為 4.679999999979145e-06
# 第 60 次，S = 600 時，執行的時間為 4.220000000287882e-06
# 第 61 次，S = 610 時，執行的時間為 3.5799999999142074e-06
# 第 62 次，S = 620 時，執行的時間為 3.42000000017606e-06
# 第 63 次，S = 630 時，執行的時間為 4.080000000072914e-06
# 第 64 次，S = 640 時，執行的時間為 4.0199999993717485e-06
# 第 65 次，S = 650 時，執行的時間為 3.5399999994467634e-06
# 第 66 次，S = 660 時，執行的時間為 3.399999999942338e-06
# 第 67 次，S = 670 時，執行的時間為 3.8799999998673226e-06
# 第 68 次，S = 680 時，執行的時間為 3.5399999994467634e-06
# 第 69 次，S = 690 時，執行的時間為 4.699999999502325e-06
# 第 70 次，S = 700 時，執行的時間為 3.6399999999048306e-06
# 第 71 次，S = 710 時，執行的時間為 3.500000000400405e-06
# 第 72 次，S = 720 時，執行的時間為 3.919999999624224e-06
# 第 73 次，S = 730 時，執行的時間為 3.6600000001385523e-06
# 第 74 次，S = 740 時，執行的時間為 3.960000000091668e-06
# 第 75 次，S = 750 時，執行的時間為 3.859999999633601e-06
# 第 76 次，S = 760 時，執行的時間為 4.03999999960547e-06
# 第 77 次，S = 770 時，執行的時間為 3.820000000587243e-06
# 第 78 次，S = 780 時，執行的時間為 3.719999999418633e-06
# 第 79 次，S = 790 時，執行的時間為 3.6399999999048306e-06
# 第 80 次，S = 800 時，執行的時間為 3.840000000110421e-06
# 第 81 次，S = 810 時，執行的時間為 4.8599999999510144e-06
# 第 82 次，S = 820 時，執行的時間為 3.999999999848569e-06
# 第 83 次，S = 830 時，執行的時間為 4.200000000054161e-06
# 第 84 次，S = 840 時，執行的時間為 1.0520000000013852e-05
# 第 85 次，S = 850 時，執行的時間為 5.439999999623524e-06
# 第 86 次，S = 860 時，執行的時間為 4.840000000427836e-06
# 第 87 次，S = 870 時，執行的時間為 4.279999999567963e-06
# 第 88 次，S = 880 時，執行的時間為 3.919999999624224e-06
# 第 89 次，S = 890 時，執行的時間為 3.480000000166683e-06
# 第 90 次，S = 900 時，執行的時間為 4.079999999362371e-06
# 第 91 次，S = 910 時，執行的時間為 3.5599999996804854e-06
# 第 92 次，S = 920 時，執行的時間為 4.119999999829815e-06
# 第 93 次，S = 930 時，執行的時間為 3.6999999998954534e-06
# 第 94 次，S = 940 時，執行的時間為 4.600000000465343e-06
# 第 95 次，S = 950 時，執行的時間為 4.520000000240998e-06
# 第 96 次，S = 960 時，執行的時間為 4.979999999932261e-06
# 第 97 次，S = 970 時，執行的時間為 4.180000000530981e-06
# 第 98 次，S = 980 時，執行的時間為 3.6399999999048306e-06
# 第 99 次，S = 990 時，執行的時間為 3.6399999999048306e-06
# 第 100 次，S = 1000 時，執行的時間為 4.899999999707916e-06
# 總執行時間：0.039024 秒
