# %%
import random
import time
import timeit

start = time.time()
 
def fibonacciSearch(arr, x):
 
    # Initialize fibonacci numbers
    fib2 = 0  # 第 (n-2) 個 Fibonacci 數
    fib1 = 1  # 第 (n-1) 個 Fibonacci 數
    fib = fib2 + fib1  # 第 n 個 Fibonacci 數
 
    # fib is going to store the smallest
    # Fibonacci Number greater than or equal to n
    while (fib < len(arr)):
        fib2 = fib1
        fib1 = fib
        fib = fib2 + fib1
 
    # Marks the eliminated range from front
    offset = -1
 
    # while there are elements to be inspected.
    # Note that we compare arr[fib2] with x.
    # When fib becomes 1, fib2 becomes 0
    while (fib > 1):
 
        # Check if fib2 is a valid location
        i = min(offset + fib2, len(arr) - 1)
 
        # If x is greater than the value at
        # index fib2, cut the subarray array
        # from offset to i
        if (arr[i] < x):
            fib = fib1
            fib1 = fib2
            fib2 = fib - fib1
            offset = i
 
        # If x is less than the value at
        # index fib2, cut the subarray
        # after i+1
        elif (arr[i] > x):
            fib = fib2
            fib1 = fib1 - fib2
            fib2 = fib - fib1
 
        # 找到該元素，return i
        else:
            return i
 
    # comparing the last element with x */
    if(fib1 and arr[len(arr) - 1] == x):
        return len(arr) - 1
 
    # 找不到該元素，return -1
    return -1

n_values = range(10, 1010, 10)
fibonacci_times = []

# Loop over different n values
for n in n_values:

    # Initialize list S with random integers
    S = [random.randint(1, 1000) for _ in range(n)]

    # 選擇 integer x
    x = random.randint(1, 1000)

    # 執行演算法5次，並計算平均執行時間
    fibonacci_time = timeit.timeit(lambda: fibonacciSearch(S, x), number = 5) / 5

    # 將每一次的平均執行時間 Append 到 list 中
    fibonacci_times.append(fibonacci_time)
    print("S = ", len(fibonacci_times) * 10, "時，執行的時間為", fibonacci_times[(n // 10) - 1])

# 結束測量
end = time.time()

# 輸出結果
print("總執行時間：%f 秒" % (end - start))
# Out:
# S =  10 時，執行的時間為 1.9799999790848233e-06
# S =  20 時，執行的時間為 1.9799999790848233e-06
# S =  30 時，執行的時間為 1.920000067912042e-06
# S =  40 時，執行的時間為 2.1000001652282664e-06
# S =  50 時，執行的時間為 2.13999992411118e-06
# S =  60 時，執行的時間為 2.8799999199691228e-06
# S =  70 時，執行的時間為 2.559999848017469e-06
# S =  80 時，執行的時間為 2.499999936844688e-06
# S =  90 時，執行的時間為 2.499999936844688e-06
# S =  100 時，執行的時間為 2.6400000933790578e-06
# S =  110 時，執行的時間為 2.4199998733820394e-06
# S =  120 時，執行的時間為 3.199999991920777e-06
# S =  130 時，執行的時間為 2.6400000933790578e-06
# S =  140 時，執行的時間為 2.7600000976235607e-06
# S =  150 時，執行的時間為 2.739999945333693e-06
# S =  160 時，執行的時間為 2.8000000384054148e-06
# S =  170 時，執行的時間為 3.4199998481199146e-06
# S =  180 時，執行的時間為 3.400000059627928e-06
# S =  190 時，執行的時間為 2.5400000595254824e-06
# S =  200 時，執行的時間為 3.139999898849055e-06
# S =  210 時，執行的時間為 2.8799999199691228e-06
# S =  220 時，執行的時間為 2.8799999199691228e-06
# S =  230 時，執行的時間為 2.5800000003073364e-06
# S =  240 時，執行的時間為 3.7800000427523628e-06
# S =  250 時，執行的時間為 2.8200000087963415e-06
# S =  260 時，執行的時間為 3.2199999623117036e-06
# S =  270 時，執行的時間為 3.1600000511389224e-06
# S =  280 時，執行的時間為 5.720000081055332e-06
# S =  290 時，執行的時間為 4.2800000301213e-06
# S =  300 時，執行的時間為 3.6600000385078602e-06
# S =  310 時，執行的時間為 3.3599999369471334e-06
# S =  320 時，執行的時間為 4.219999937049579e-06
# S =  330 時，執行的時間為 3.04000004689442e-06
# S =  340 時，執行的時間為 3.680000008898787e-06
# S =  350 時，執行的時間為 3.1800000215298496e-06
# S =  360 時，執行的時間為 3.5400000342633577e-06
# S =  370 時，執行的時間為 3.459999970800709e-06
# S =  380 時，執行的時間為 3.3199999961652794e-06
# S =  390 時，執行的時間為 4.599999920174014e-06
# S =  400 時，執行的時間為 4.380000063974876e-06
# S =  410 時，執行的時間為 4.5400000090012325e-06
# S =  420 時，執行的時間為 4.5800001316820275e-06
# S =  430 時，執行的時間為 5.7999999626190405e-06
# S =  440 時，執行的時間為 4.439999975147657e-06
# S =  450 時，執行的時間為 6.8199999077478425e-06
# S =  460 時，執行的時間為 4.400000034365803e-06
# S =  470 時，執行的時間為 6.22000006842427e-06
# S =  480 時，執行的時間為 4.259999877831433e-06
# S =  490 時，執行的時間為 4.380000063974876e-06
# S =  500 時，執行的時間為 4.5800001316820275e-06
# S =  510 時，執行的時間為 4.5400000090012325e-06
# S =  520 時，執行的時間為 7.619999996677506e-06
# S =  530 時，執行的時間為 4.400000034365803e-06
# S =  540 時，執行的時間為 3.80000001314329e-06
# S =  550 時，執行的時間為 3.440000000409782e-06
# S =  560 時，執行的時間為 3.1800000215298496e-06
# S =  570 時，執行的時間為 3.1199999284581283e-06
# S =  580 時，執行的時間為 4.200000148557592e-06
# S =  590 時，執行的時間為 3.339999966556206e-06
# S =  600 時，執行的時間為 3.2199999623117036e-06
# S =  610 時，執行的時間為 9.59999997576233e-06
# S =  620 時，執行的時間為 4.679999983636663e-06
# S =  630 時，執行的時間為 4.220000118948519e-06
# S =  640 時，執行的時間為 3.459999970800709e-06
# S =  650 時，執行的時間為 3.479999941191636e-06
# S =  660 時，執行的時間為 4.679999983636663e-06
# S =  670 時，執行的時間為 3.5999999454361385e-06
# S =  680 時，執行的時間為 4.160000025876798e-06
# S =  690 時，執行的時間為 3.680000008898787e-06
# S =  700 時，執行的時間為 3.2800000553834254e-06
# S =  710 時，執行的時間為 4.1799999962677244e-06
# S =  720 時，執行的時間為 3.240000114601571e-06
# S =  730 時，執行的時間為 3.3800000892370007e-06
# S =  740 時，執行的時間為 3.199999991920777e-06
# S =  750 時，執行的時間為 3.360000118846074e-06
# S =  760 時，執行的時間為 3.7600000723614356e-06
# S =  770 時，執行的時間為 3.80000001314329e-06
# S =  780 時，執行的時間為 3.7600000723614356e-06
# S =  790 時，執行的時間為 3.6200000977260062e-06
# S =  800 時，執行的時間為 3.6599998566089197e-06
# S =  810 時，執行的時間為 6.120000034570694e-06
# S =  820 時，執行的時間為 3.859999924316071e-06
# S =  830 時，執行的時間為 3.80000001314329e-06
# S =  840 時，執行的時間為 4.55999997939216e-06
# S =  850 時，執行的時間為 3.2199999623117036e-06
# S =  860 時，執行的時間為 4.240000089339447e-06
# S =  870 時，執行的時間為 3.960000140068587e-06
# S =  880 時，執行的時間為 3.2800000553834254e-06
# S =  890 時，執行的時間為 3.1800000215298496e-06
# S =  900 時，執行的時間為 4.5400000090012325e-06
# S =  910 時，執行的時間為 3.3599999369471334e-06
# S =  920 時，執行的時間為 3.5799999750452117e-06
# S =  930 時，執行的時間為 4.160000025876798e-06
# S =  940 時，執行的時間為 3.300000025774352e-06
# S =  950 時，執行的時間為 4.699999954027589e-06
# S =  960 時，執行的時間為 2.7400001272326335e-06
# S =  970 時，執行的時間為 3.900000046996866e-06
# S =  980 時，執行的時間為 4.1799999962677244e-06
# S =  990 時，執行的時間為 3.9599999581696466e-06
# S =  1000 時，執行的時間為 8.019999950192868e-06
# 總執行時間：0.037898 秒
