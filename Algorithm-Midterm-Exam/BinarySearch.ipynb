# %%
import random
import time
import timeit

start = time.time()

def binarySearch(arr, x):
    low = 0
    high = len(arr) - 1    

    while low <= high:
 
        mid = (low + high) // 2
 
        if arr[mid] == x:
            return mid
 
        elif arr[mid] < x:
            low = mid + 1
 
        else:
            high = mid - 1
 
    return -1

n_values = range(10, 1010, 10)
binary_times = []

# Loop over different n values
for n in n_values:

    # Initialize list S with random integers
    S = [random.randint(1, 1000) for _ in range(n)]

    # 選擇 integer x
    x = random.randint(1, 1000)

    # 執行演算法5次，並計算平均執行時間
    binary_time = timeit.timeit(lambda: binarySearch(S, x), number = 5) / 5

    # 將每一次的平均執行時間 Append 到 list 中
    binary_times.append(binary_time)

    print("S = ", len(binary_times)*10, "時，執行的時間為", binary_times[(n // 10) - 1])

# 結束測量
end = time.time()

# 輸出結果
print("總執行時間：%f 秒" % (end - start))
# Out:
# S =  10 時，執行的時間為 8.999999408842996e-07
# S =  20 時，執行的時間為 5.160000000614673e-06
# S =  30 時，執行的時間為 8.199998774216511e-07
# S =  40 時，執行的時間為 8.999999408842996e-07
# S =  50 時，執行的時間為 8.999999408842996e-07
# S =  60 時，執行的時間為 9.999999747378752e-07
# S =  70 時，執行的時間為 9.999999747378752e-07
# S =  80 時，執行的時間為 9.60000033956021e-07
# S =  90 時，執行的時間為 3.879999894706998e-06
# S =  100 時，執行的時間為 1.0600000678095966e-06
# S =  110 時，執行的時間為 1.0799998563015833e-06
# S =  120 時，執行的時間為 1.0800000382005238e-06
# S =  130 時，執行的時間為 1.1400001312722451e-06
# S =  140 時，執行的時間為 1.0800000382005238e-06
# S =  150 時，執行的時間為 1.700000029813964e-06
# S =  160 時，執行的時間為 1.1800000720540993e-06
# S =  170 時，執行的時間為 1.1399999493733048e-06
# S =  180 時，執行的時間為 1.1399999493733048e-06
# S =  190 時，執行的時間為 1.2200000128359533e-06
# S =  200 時，執行的時間為 1.0400000974186696e-06
# S =  210 時，執行的時間為 1.0600000678095966e-06
# S =  220 時，執行的時間為 1.2399999832268803e-06
# S =  230 時，執行的時間為 1.0600000678095966e-06
# S =  240 時，執行的時間為 1.2200000128359533e-06
# S =  250 時，執行的時間為 1.1600001016631723e-06
# S =  260 時，執行的時間為 1.2799999240087346e-06
# S =  270 時，執行的時間為 1.199999860546086e-06
# S =  280 時，執行的時間為 1.4199998986441641e-06
# S =  290 時，執行的時間為 1.4399998690350913e-06
# S =  300 時，執行的時間為 1.2999998943996616e-06
# S =  310 時，執行的時間為 1.219999830937013e-06
# S =  320 時，執行的時間為 1.2000000424450263e-06
# S =  330 時，執行的時間為 1.4999999621068127e-06
# S =  340 時，執行的時間為 1.2200000128359533e-06
# S =  350 時，執行的時間為 1.179999890155159e-06
# S =  360 時，執行的時間為 1.1399999493733048e-06
# S =  370 時，執行的時間為 1.3599999874713831e-06
# S =  380 時，執行的時間為 1.2599999536178076e-06
# S =  390 時，執行的時間為 1.4599998394260183e-06
# S =  400 時，執行的時間為 1.1600001016631723e-06
# S =  410 時，執行的時間為 1.3200000466895289e-06
# S =  420 時，執行的時間為 1.1800000720540993e-06
# S =  430 時，執行的時間為 1.2399999832268803e-06
# S =  440 時，執行的時間為 1.1599999197642318e-06
# S =  450 時，執行的時間為 1.5999999959603884e-06
# S =  460 時，執行的時間為 4.380000063974876e-06
# S =  470 時，執行的時間為 1.5999999959603884e-06
# S =  480 時，執行的時間為 1.4600000213249587e-06
# S =  490 時，執行的時間為 1.2800001059076749e-06
# S =  500 時，執行的時間為 1.4600000213249587e-06
# S =  510 時，執行的時間為 1.2799999240087346e-06
# S =  520 時，執行的時間為 1.3399998351815156e-06
# S =  530 時，執行的時間為 1.5999999959603884e-06
# S =  540 時，執行的時間為 1.3200000466895289e-06
# S =  550 時，執行的時間為 1.3599999874713831e-06
# S =  560 時，執行的時間為 1.4199998986441641e-06
# S =  570 時，執行的時間為 1.4799999917158857e-06
# S =  580 時，執行的時間為 1.3599999874713831e-06
# S =  590 時，執行的時間為 1.2599999536178076e-06
# S =  600 時，執行的時間為 2.237999997305451e-05
# S =  610 時，執行的時間為 1.6599999071331694e-06
# S =  620 時，執行的時間為 1.759999940986745e-06
# S =  630 時，執行的時間為 1.5599998732795939e-06
# S =  640 時，執行的時間為 1.3000000762986019e-06
# S =  650 時，執行的時間為 1.4199998986441641e-06
# S =  660 時，執行的時間為 1.5400000847876072e-06
# S =  670 時，執行的時間為 1.5999999959603884e-06
# S =  680 時，執行的時間為 1.3599999874713831e-06
# S =  690 時，執行的時間為 1.4799999917158857e-06
# S =  700 時，執行的時間為 1.4799999917158857e-06
# S =  710 時，執行的時間為 1.5600000551785342e-06
# S =  720 時，執行的時間為 1.5800000255694612e-06
# S =  730 時，執行的時間為 1.3200000466895289e-06
# S =  740 時，執行的時間為 1.6400001186411827e-06
# S =  750 時，執行的時間為 1.4200000805431046e-06
# S =  760 時，執行的時間為 1.5600000551785342e-06
# S =  770 時，執行的時間為 1.3800001397612504e-06
# S =  780 時，執行的時間為 4.239999907440506e-06
# S =  790 時，執行的時間為 1.720000000204891e-06
# S =  800 時，執行的時間為 1.2999998943996616e-06
# S =  810 時，執行的時間為 1.1399999493733048e-06
# S =  820 時，執行的時間為 1.5999999959603884e-06
# S =  830 時，執行的時間為 1.3200000466895289e-06
# S =  840 時，執行的時間為 1.3199998647905886e-06
# S =  850 時，執行的時間為 1.5799998436705209e-06
# S =  860 時，執行的時間為 1.4400000509340316e-06
# S =  870 時，執行的時間為 1.6400001186411827e-06
# S =  880 時，執行的時間為 1.5600000551785342e-06
# S =  890 時，執行的時間為 1.5400000847876072e-06
# S =  900 時，執行的時間為 1.5400000847876072e-06
# S =  910 時，執行的時間為 1.3800001397612504e-06
# S =  920 時，執行的時間為 1.5800000255694612e-06
# S =  930 時，執行的時間為 1.3200000466895289e-06
# S =  940 時，執行的時間為 4.719999924418516e-06
# S =  950 時，執行的時間為 1.720000000204891e-06
# S =  960 時，執行的時間為 1.720000000204891e-06
# S =  970 時，執行的時間為 1.5400000847876072e-06
# S =  980 時，執行的時間為 1.6600000890321097e-06
# S =  990 時，執行的時間為 1.5999999959603884e-06
# S =  1000 時，執行的時間為 1.5599998732795939e-06
# 總執行時間：0.037886 秒
