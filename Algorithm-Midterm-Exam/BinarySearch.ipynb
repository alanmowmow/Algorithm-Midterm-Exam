# %%
import random
import time
import timeit

start = time.time()

def binarySearch(arr, x):
    low = 0
    high = len(arr) - 1    

    while low <= high:
 
        mid = (low + high) // 2
 
        if arr[mid] == x:
            return mid
 
        elif arr[mid] < x:
            low = mid + 1
 
        else:
            high = mid - 1
 
    return -1

n_values = range(10, 1010, 10)
binary_times = []

# Loop over different n values
for n in n_values:

    # Initialize list S with random integers
    S = [random.randint(1, 1000) for _ in range(n)]

    # 選擇 integer x
    x = random.randint(1, 1000)

    # 執行演算法5次，並計算平均執行時間
    binary_time = timeit.timeit(lambda: binarySearch(S, x), number = 5) / 5

    # 將每一次的平均執行時間 Append 到 list 中
    binary_times.append(binary_time)

    print("第", len(binary_times), "次，S =", len(binary_times)*10, "時，執行的時間為", binary_times[(n // 10) - 1])

# 結束測量
end = time.time()

# 輸出結果
print("總執行時間：%f 秒" % (end - start))
# Out:
# 第 1 次，S = 10 時，執行的時間為 9.399999999937236e-07
# 第 2 次，S = 20 時，執行的時間為 8.599999999914232e-07
# 第 3 次，S = 30 時，執行的時間為 8.599999999914232e-07
# 第 4 次，S = 40 時，執行的時間為 9.399999999937236e-07
# 第 5 次，S = 50 時，執行的時間為 8.400000000019503e-07
# 第 6 次，S = 60 時，執行的時間為 9.800000000170782e-07
# 第 7 次，S = 70 時，執行的時間為 9.60000000005401e-07
# 第 8 次，S = 80 時，執行的時間為 1.0799999999866472e-06
# 第 9 次，S = 90 時，執行的時間為 9.800000000170782e-07
# 第 10 次，S = 100 時，執行的時間為 1.180000000000625e-06
# 第 11 次，S = 110 時，執行的時間為 3.2199999999926733e-06
# 第 12 次，S = 120 時，執行的時間為 2.6000000000081515e-06
# 第 13 次，S = 130 時，執行的時間為 1.1600000000111522e-06
# 第 14 次，S = 140 時，執行的時間為 1.0799999999866472e-06
# 第 15 次，S = 150 時，執行的時間為 1.2200000000017751e-06
# 第 16 次，S = 160 時，執行的時間為 1.1599999999889476e-06
# 第 17 次，S = 170 時，執行的時間為 1.199999999990098e-06
# 第 18 次，S = 180 時，執行的時間為 1.1599999999889476e-06
# 第 19 次，S = 190 時，執行的時間為 2.3200000000000998e-06
# 第 20 次，S = 200 時，執行的時間為 1.3599999999946987e-06
# 第 21 次，S = 210 時，執行的時間為 1.3400000000052259e-06
# 第 22 次，S = 220 時，執行的時間為 1.3600000000169033e-06
# 第 23 次，S = 230 時，執行的時間為 1.2799999999923983e-06
# 第 24 次，S = 240 時，執行的時間為 1.239999999991248e-06
# 第 25 次，S = 250 時，執行的時間為 1.2000000000123023e-06
# 第 26 次，S = 260 時，執行的時間為 1.3399999999830215e-06
# 第 27 次，S = 270 時，執行的時間為 1.3199999999935486e-06
# 第 28 次，S = 280 時，執行的時間為 1.2999999999818712e-06
# 第 29 次，S = 290 時，執行的時間為 1.619999999991073e-06
# 第 30 次，S = 300 時，執行的時間為 1.940000000000275e-06
# 第 31 次，S = 310 時，執行的時間為 1.3199999999935486e-06
# 第 32 次，S = 320 時，執行的時間為 1.6000000000016002e-06
# 第 33 次，S = 330 時，執行的時間為 1.4799999999981495e-06
# 第 34 次，S = 340 時，執行的時間為 1.2600000000029254e-06
# 第 35 次，S = 350 時，執行的時間為 1.4200000000075263e-06
# 第 36 次，S = 360 時，執行的時間為 1.259999999980721e-06
# 第 37 次，S = 370 時，執行的時間為 1.3599999999946987e-06
# 第 38 次，S = 380 時，執行的時間為 1.4999999999876223e-06
# 第 39 次，S = 390 時，執行的時間為 1.6400000000027503e-06
# 第 40 次，S = 400 時，執行的時間為 1.619999999991073e-06
# 第 41 次，S = 410 時，執行的時間為 1.3800000000063762e-06
# 第 42 次，S = 420 時，執行的時間為 1.480000000020354e-06
# 第 43 次，S = 430 時，執行的時間為 1.4200000000075263e-06
# 第 44 次，S = 440 時，執行的時間為 1.4200000000075263e-06
# 第 45 次，S = 450 時，執行的時間為 1.5200000000215041e-06
# 第 46 次，S = 460 時，執行的時間為 1.540000000010977e-06
# 第 47 次，S = 470 時，執行的時間為 1.6000000000016002e-06
# 第 48 次，S = 480 時，執行的時間為 1.3600000000169033e-06
# 第 49 次，S = 490 時，執行的時間為 2.0400000000142525e-06
# 第 50 次，S = 500 時，執行的時間為 1.2999999999818712e-06
# 第 51 次，S = 510 時，執行的時間為 1.6200000000132774e-06
# 第 52 次，S = 520 時，執行的時間為 1.6800000000039006e-06
# 第 53 次，S = 530 時，執行的時間為 1.7399999999945238e-06
# 第 54 次，S = 540 時，執行的時間為 1.6400000000027503e-06
# 第 55 次，S = 550 時，執行的時間為 1.8800000000096517e-06
# 第 56 次，S = 560 時，執行的時間為 1.7599999999839967e-06
# 第 57 次，S = 570 時，執行的時間為 1.7800000000178784e-06
# 第 58 次，S = 580 時，執行的時間為 1.679999999981696e-06
# 第 59 次，S = 590 時，執行的時間為 2.4000000000024004e-06
# 第 60 次，S = 600 時，執行的時間為 1.6999999999933735e-06
# 第 61 次，S = 610 時，執行的時間為 8.600000000136276e-07
# 第 62 次，S = 620 時，執行的時間為 1.7399999999945238e-06
# 第 63 次，S = 630 時，執行的時間為 1.6000000000016002e-06
# 第 64 次，S = 640 時，執行的時間為 1.7399999999945238e-06
# 第 65 次，S = 650 時，執行的時間為 1.6400000000027503e-06
# 第 66 次，S = 660 時，執行的時間為 1.700000000015578e-06
# 第 67 次，S = 670 時，執行的時間為 1.5800000000121273e-06
# 第 68 次，S = 680 時，執行的時間為 1.5199999999992998e-06
# 第 69 次，S = 690 時，執行的時間為 1.5399999999887727e-06
# 第 70 次，S = 700 時，執行的時間為 1.8199999999968242e-06
# 第 71 次，S = 710 時，執行的時間為 1.6600000000144277e-06
# 第 72 次，S = 720 時，執行的時間為 3.4199999999984244e-06
# 第 73 次，S = 730 時，執行的時間為 3.4199999999984244e-06
# 第 74 次，S = 740 時，執行的時間為 1.920000000010802e-06
# 第 75 次，S = 750 時，執行的時間為 1.920000000010802e-06
# 第 76 次，S = 760 時，執行的時間為 2.0000000000131022e-06
# 第 77 次，S = 770 時，執行的時間為 2.019999999980371e-06
# 第 78 次，S = 780 時，執行的時間為 1.8799999999874472e-06
# 第 79 次，S = 790 時，執行的時間為 2.080000000015403e-06
# 第 80 次，S = 800 時，執行的時間為 1.959999999989748e-06
# 第 81 次，S = 810 時，執行的時間為 1.8999999999991246e-06
# 第 82 次，S = 820 時，執行的時間為 1.8599999999979743e-06
# 第 83 次，S = 830 時，執行的時間為 1.839999999986297e-06
# 第 84 次，S = 840 時，執行的時間為 2.1800000000071764e-06
# 第 85 次，S = 850 時，執行的時間為 1.8600000000201788e-06
# 第 86 次，S = 860 時，執行的時間為 1.8999999999991246e-06
# 第 87 次，S = 870 時，執行的時間為 1.9800000000014252e-06
# 第 88 次，S = 880 時，執行的時間為 1.6800000000039006e-06
# 第 89 次，S = 890 時，執行的時間為 2.059999999981521e-06
# 第 90 次，S = 900 時，執行的時間為 1.7799999999956739e-06
# 第 91 次，S = 910 時，執行的時間為 2.239999999997799e-06
# 第 92 次，S = 920 時，執行的時間為 2.3399999999895726e-06
# 第 93 次，S = 930 時，執行的時間為 2.7800000000022252e-06
# 第 94 次，S = 940 時，執行的時間為 2.0600000000037254e-06
# 第 95 次，S = 950 時，執行的時間為 1.8599999999979743e-06
# 第 96 次，S = 960 時，執行的時間為 1.7799999999956739e-06
# 第 97 次，S = 970 時，執行的時間為 2.020000000002575e-06
# 第 98 次，S = 980 時，執行的時間為 2.259999999987272e-06
# 第 99 次，S = 990 時，執行的時間為 2.2000000000188534e-06
# 第 100 次，S = 1000 時，執行的時間為 2.0600000000037254e-06
# 總執行時間：0.044880 秒
